# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./datasets/Crucial_Elements.csv', index_col=0)
df = df.drop(df.index[0], axis=0)
df.tail()
# Out:
#                      total_amount  trip_distance  fare_amount  tolls_amount  \
# 2020-06-30 19:00:00     15.954686       2.401137     9.870901      0.000000
# 2020-06-30 20:00:00     15.718408       2.364177     9.769862      0.000000
# 2020-06-30 21:00:00     14.993762       2.712161    10.621107      0.003571
# 2020-06-30 22:00:00     15.704196       2.945819    11.237284      0.006034
# 2020-06-30 23:00:00     16.295517       2.988082    11.428164      0.000000
#
#                      tip_amount  Brooklyn_PU  Manhattan_PU  Queens_PU  \
# 2020-06-30 19:00:00    1.833676     0.009099      0.976342   0.013649
# 2020-06-30 20:00:00    1.701909     0.008299      0.957123   0.031812
# 2020-06-30 21:00:00    1.616125     0.008929      0.939286   0.039286
# 2020-06-30 22:00:00    1.635819     0.006466      0.922414   0.058190
# 2020-06-30 23:00:00    1.597562     0.019178      0.893151   0.068493
#
#                      Staten_Island_PU  Bronx_DO  Brooklyn_DO  Manhattan_DO  \
# ...

# %% [markdown]
# I created dummy variables in my data wrangling to help study what the data looks like and to check how they correlated to the target variable.

# %% [markdown]
# # Standardizing the magnitude

# %%
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#    total_amount  trip_distance  fare_amount  tolls_amount  tip_amount  \
# 0      0.885796      -0.027912     0.437501     -0.214885    1.315357
# 1      1.004708       0.127004     0.315116     -0.069906    1.267848
# 2      0.826532       0.251179     0.309303     -0.094525    1.025295
# 3      0.771972       0.410612     0.394185     -0.043923    0.521331
# 4      0.750867       0.532663     0.394218     -0.100444   -0.281626
#
#    Brooklyn_PU  Manhattan_PU  Queens_PU  Staten_Island_PU  Bronx_DO  \
# 0     0.374369      0.207345  -0.679667         -0.074548 -0.544620
# 1     0.638116     -0.027822  -0.426011         -0.074548 -0.511267
# 2     0.375325      0.077969  -0.338959         -0.074548 -0.455398
# 3     0.417148     -0.028700  -0.051167         -0.074548 -0.453874
# 4     0.410655     -0.578600   1.409244         -0.074548 -0.440623
#
#    Brooklyn_DO  Manhattan_DO  Queens_DO  Staten_Island_DO  Mins_In_Ride
# ...

# %%
len(df.columns)
# Out:
# 15

# %%
scalar = StandardScaler()
indecies = df.index
X = df.drop('total_amount', axis=1)
y = df['total_amount']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)
X_train.head()

# Join X_train and y_train into one dataframe
training_data = X_train.join(y_train)
# Same with the testing data
testing_data = X_test.join(y_test)

# Fit on the training data 
scalar.fit(training_data)

# Transform on the training and testing data
training_data = scalar.transform(training_data)
testing_data = scalar.transform(testing_data)

# Turning it back into a dataframe to be able to write it into a fiile
training_data = pd.DataFrame(training_data, columns=df.columns, index=indecies[:len(X_train)])
testing_data = pd.DataFrame(testing_data, columns=df.columns, index=indecies[len(X_train):])
testing_data.tail()
# Out:
#                      total_amount  trip_distance  fare_amount  tolls_amount  \
# 2020-06-30 19:00:00     -0.235090      -0.131696    -0.234804      1.757663
# 2020-06-30 20:00:00     -0.745289      -0.574427    -0.129806      0.502090
# 2020-06-30 21:00:00     -0.595185      -0.635155    -0.037099      0.047802
# 2020-06-30 22:00:00      0.266817       0.037028    -0.271462      0.296296
# 2020-06-30 23:00:00      0.572194       0.142182    -0.271462     -1.469716
#
#                      tip_amount  Brooklyn_PU  Manhattan_PU  Queens_PU  \
# 2020-06-30 19:00:00   -0.351197     0.591311     -0.630848  -0.071594
# 2020-06-30 20:00:00   -0.321534     0.510580     -0.490913  -0.071594
# 2020-06-30 21:00:00   -0.446498     0.436373     -0.161345  -0.071594
# 2020-06-30 22:00:00   -0.324876     0.135017      0.475288  -0.071594
# 2020-06-30 23:00:00   -0.198958     0.515298     -0.614721  -0.071594
#
#                      Staten_Island_PU  Bronx_DO  Brooklyn_DO  Manhattan_DO  \
# ...

# %%
training_data.to_csv('./datasets/Train_Data.csv')
testing_data.to_csv('./datasets/Test_Data.csv')
