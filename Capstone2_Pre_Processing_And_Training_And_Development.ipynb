# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./datasets/Crucial_Elements.csv', index_col=0)
df = df.drop(df.index[0], axis=0)
df.head()
# Out:
#                      total_amount  trip_distance  fare_amount  tolls_amount  \
# 2020-01-01 01:00:00     16.936198       2.564234    11.581830      0.000405
# 2020-01-01 02:00:00     17.148780       2.690488    11.325833      0.001363
# 2020-01-01 03:00:00     16.830250       2.791689    11.313673      0.001200
# 2020-01-01 04:00:00     16.732711       2.921626    11.491224      0.001534
# 2020-01-01 05:00:00     16.694981       3.021095    11.491293      0.001161
#
#                      tip_amount  Brooklyn_PU  Manhattan_PU  Queens_PU  \
# 2020-01-01 01:00:00    1.958635     0.043406      0.935325   0.018230
# 2020-01-01 02:00:00    1.940590     0.053938      0.916782   0.025468
# 2020-01-01 03:00:00    1.848462     0.043444      0.925123   0.027952
# 2020-01-01 04:00:00    1.657045     0.045114      0.916712   0.036164
# 2020-01-01 05:00:00    1.352062     0.044855      0.873351   0.077836
#
#                      Staten_Island_PU  Bronx_DO  Brooklyn_DO  Manhattan_DO  \
# ...

# %% [markdown]
# I created dummy variables in my data wrangling to help study what the data looks like and to check how they correlated to the target variable.

# %% [markdown]
# # Standardizing the magnitude

# %%
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#    total_amount  trip_distance  fare_amount  tolls_amount  tip_amount  \
# 0      0.885796      -0.027912     0.437501     -0.214885    1.315357
# 1      1.004708       0.127004     0.315116     -0.069906    1.267848
# 2      0.826532       0.251179     0.309303     -0.094525    1.025295
# 3      0.771972       0.410612     0.394185     -0.043923    0.521331
# 4      0.750867       0.532663     0.394218     -0.100444   -0.281626
#
#    Brooklyn_PU  Manhattan_PU  Queens_PU  Staten_Island_PU  Bronx_DO  \
# 0     0.374369      0.207345  -0.679667         -0.074548 -0.544620
# 1     0.638116     -0.027822  -0.426011         -0.074548 -0.511267
# 2     0.375325      0.077969  -0.338959         -0.074548 -0.455398
# 3     0.417148     -0.028700  -0.051167         -0.074548 -0.453874
# 4     0.410655     -0.578600   1.409244         -0.074548 -0.440623
#
#    Brooklyn_DO  Manhattan_DO  Queens_DO  Staten_Island_DO  Mins_In_Ride
# ...

# %%
X = scaled_df.drop('total_amount', axis=1)
y = scaled_df['total_amount']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
(X_train.shape, y_train.shape)
# Out:
# ((3056, 14), (3056,))

# %%
(X_test.shape, y_test.shape)
# Out:
# ((1311, 14), (1311,))

# %%
crucial_elements.to_csv('./datasets/Crucial_Elements.csv')

# %%
X_train.join(y_train).to_csv('./datasets/Train_Data.csv')
X_test.join(y_test).to_csv('./')
# Out:
#       trip_distance  fare_amount  tolls_amount  tip_amount  Brooklyn_PU  \
# 3198       0.673660     0.494988      0.390363   -0.864409     1.531756
# 3530       4.625330     5.044336      6.051385   -2.244365     5.267693
# 1398      -0.730845    -0.425233     -0.146603    0.738260    -0.340001
# 3484       1.803082     1.844696     -0.276224   -2.469801     3.706654
# 3269       1.268187     0.922534     -0.276224   -1.786030     1.887949
# ...             ...          ...           ...         ...          ...
# 3444      -0.485195    -0.749493     -0.276224   -0.424151    -0.148605
# 466       -0.962069    -0.851736     -0.235274    0.281880    -0.591363
# 3092       0.269241    -0.015698     -0.276224   -0.632674     0.544336
# 3772       1.561883     1.157238     -0.276224   -1.583913     0.836399
# 860       -0.297692    -0.119026     -0.047996    1.874050    -0.427593
#
#       Manhattan_PU  Queens_PU  Staten_Island_PU  Bronx_DO  Brooklyn_DO  \
# ...
